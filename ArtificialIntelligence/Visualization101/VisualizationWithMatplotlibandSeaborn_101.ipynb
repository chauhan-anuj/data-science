# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt

xs=[0,1,2]
ys=[100,200,300]


plt.plot(xs,ys,color='red',marker="*",markersize=12,linestyle="--")
plt.title("Attendance")
plt.xlabel("Time Period")
plt.ylabel("Attendance")

plt.xlim(0,2)
plt.ylim(100,300)

plt.show()
